# %%
data = [10 , "python" , 3.14 , True , None , [1,2] , (7,8) , "AI"]

print(data)
# Out:
# [10, 'python', 3.14, True, None, [7, 8], (1, 2), 'AI']

# %%
data = [10 , "python" , 3.14 , True , None , [1,2] , (7,8) , "AI"]

print(len(data))
# Out:
# 8

# %%
data = [10 , "python" , 3.14 , True , None , [7,8] , (1,2) , "AI"]

print(len(data[0:5:1]))
# Out:
# 5

# %%
def deer(name, age):
    print(f"My name is {name} and i am {age} years old")

deer('deeraj', 23)

print1 = str(deer('ram' , 22))
print(print1)
# Out:
# My name is deeraj and i am 23 years old
# My name is ram and i am 22 years old
# None
