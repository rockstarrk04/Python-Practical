# %%
num = 45
if num > 0:
    print(f'{num} is positive ')
# Out:
# 45 is positive

# %%
num = int(input('enter a num: '))
if num > 0:
    print(f'{num} is positive')
# Out:
# 70 is positive

# %%
num = eval(input('enter a num: '))
if num > 0:
    print(f'{num} is positive')
# Out:
# 453 is positive

# %%
num = -90
if num < 0:
    print(f'{num} is negative')
# Out:
# -90 is negative

# %%
num = 0
if num == 0:
    print(f'{num} is equal to 0')
# Out:
# 0 is equal to 0

# %%
num = 98
if (num % 2 == 0):
    print(f'{num} is divisible by 2')
# Out:
# 98 is divisible by 2

# %%
num = 99
if (num % 2 != 0):
    print(f'{num} is divisible by 2')
# Out:
# 99 is divisible by 2

# %%
ename = 'Ram'
age = 22
if age > 18:
    print(f'employee name is {ename}')
# Out:
# employee name is Ram

# %%
num = 30
if (num % 3 == 0):
    print('fizz')
# Out:
# fizz

# %%
num = 30
if (num % 5 == 0):
    print('buzz')
# Out:
# buzz

# %%
num = 30
if (num % 3 == 0) and (num % 5 == 0):
    print('FizzBuzz')
# Out:
# FizzBuzz

# %%
s1 = 'apple'
if (s1[0] in 'aeiouAEIOU'):
    print(f'{s1} starts with vowel')
# Out:
# apple starts with vowel

# %%
s1 = 'microsoft'
if (s1[0] not in 'aeiouAEIOU'):
    print(f'{s1} starts with consonants')
# Out:
# microsoft starts with consonants

# %%
s1 = 'apple'
if (s1[-1] in 'aeiouAEIOU'):
    print(f'{s1} ends with vowel')
# Out:
# apple ends with vowel

# %%
s1 = 'microsoft'
if (s1[-1] not in 'aeiouAEIOU'):
    print(f'{s1} ends with consonants')
# Out:
# microsoft ends with consonants

# %%
s1 = 'Python'
if (s1[0] >= 'A' and s1[0] <= 'Z'):
    print(f'{s1} starts with uppercase')
# Out:
# Python starts with uppercase

# %%
s1 = 'Python'
if ('A' <= s1[0] <= 'Z'):
    print(f'{s1} starts with uppercase')
# Out:
# Python starts with uppercase

# %%
s1 = 'Python'
if ('a' <= s1[-1] <= 'z'):
    print(f'{s1} ends with lowercase')
# Out:
# Python ends with lowercase

# %%
val = {1,2,4,5}
if type(val) in [str,list,set,dict,tuple] :
    print("val is a MVDT")
# Out:
# <class 'set'>
# val is a MVDT

# %%
num = int(input())
if 5 > num > 1:
    print("Hello Python")
