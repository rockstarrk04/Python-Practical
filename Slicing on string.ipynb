# %%
message = 'hello world'
print(message[4::-1])
# Out:
# olleh

# %%
a = 'welcome to python class'
print(a[0:7:1])
# Out:
# welcome

# %%
a = 'welcome to python class'
print(a[3:10:1])
# Out:
# come to

# %%
a = 'welcome to python class'
print(a[11:17:1])
# Out:
# python

# %%
a = 'welcome to python class'
print(a[0:24:2])
# Out:
# wloet yhncas

# %%
a = 'welcome to python class'
print(a[0:24:3])
# Out:
# wceoyocs

# %%
a = 'welcome to python class'
print(a[8:10:1])
# Out:
# to

# %%
a = 'welcome to python class'
print(a[18:23:1])
# Out:
# class

# %%
a = 'welcome to python class'
print(a[18:23:1])
# Out:
# class

# %%
a = 'welcome to python class'
print(a[2:15:2])
# Out:
# loet yh

# %%
a = 'welcome to python class'
print(a[5:20:3])
# Out:
# mtph

# %%
a = 'welcome to python class'
print(a[0:24:1])
# Out:
# welcome to python class

# %%
a = 'welcome to python class'
print(len(a))
print(a[::1])
# Out:
# 23
# welcome to python class
