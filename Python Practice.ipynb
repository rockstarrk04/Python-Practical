# %% [markdown]
# **This is the first program**

# %%
print('Hello World')
# Out:
# Hello World

# %%
print(90)
# Out:
# 90

# %%
msg = 'Ramkumar'
print(msg)
print(len(msg))
print(type(msg))
print(msg[0])
print(msg[-2])
print(msg[0] + msg[-1])
print(msg[::-1])
print(msg[:-8:-1])
# Out:
# Ramkumar
# 8
# <class 'str'>
# R
# a
# Rr
# ramukmaR
# ramukma
